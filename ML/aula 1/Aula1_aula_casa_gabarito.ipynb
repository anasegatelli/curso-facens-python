# %% [markdown]
# # **Expectativa de Vida (OMS)**
#
# O conjunto de dados relacionado à expectativa de vida e aos fatores de saúde de 193 países foi coletado do mesmo site do repositório de dados da OMS, e os dados econômicos correspondentes foram coletados do site das Nações Unidas.
#
#
#
# Dentre todas as categorias de fatores relacionados à saúde, foram selecionados apenas os fatores críticos mais representativos. Observou-se que, nos últimos 15 anos, houve um grande desenvolvimento no setor de saúde, resultando na redução das taxas de mortalidade humana, especialmente nos países em desenvolvimento, em comparação com os últimos 30 anos. Portanto, neste projeto, consideramos dados do período de 2000 a 2015 para 193 países para análises posteriores.

# %% [markdown]
# # **Explicação das Colunas**
#
#
# * Country - País
# * Year - Idade
# * Status - Status de país desenvolvido ou em desenvolvimento
# * Life expectancy - Expectativa de vida por idade
# * Adult Mortality - Taxa de mortalidade adulta para ambos os sexos (probabilidade de morte entre 15 e 60 anos por 1000 habitantes)
# * infant deaths - Número de mortes infantis por 1000 habitantes
# * Alcohol - Álcool, consumo per capita (15+) registado (em litros de álcool puro)
# * percentage expenditure - Percentual de Gastos, despesas com saúde como porcentagem do Produto Interno Bruto per capita (%)
# * Hepatitis B - Cobertura vacinal contra hepatite B (HepB) em crianças de 1 ano de idade (%)
# * Measles - Sarampo, número de casos notificados por 1000 habitantes.
# * BMI - IMC, Índice de Massa Corporal médio de toda a população
# * under-five deaths - Número de mortes de crianças menores de cinco anos por 1000 habitantes
# * Polio - Cobertura vacinal contra a poliomielite (Pol3) em crianças de 1 ano de idade (%)
# * Total expenditure - Despesas do governo geral com saúde como porcentagem das despesas totais do governo (%)
# * Diphtheria - Cobertura da vacinação contra difteria, tétano e coqueluche (DTP3) em crianças de 1 ano de idade (%)
# * HIV/AIDS - Mortes por 1.000 nascidos vivos por HIV/AIDS (0-4 anos)
# * GDP - PIB, Produto Interno Bruto per capita (em USD)
# * Population - População do País
# * thinness  1-19 years - Magreza 10 - 19 anos, prevalência de magreza entre crianças e adolescentes de 10 a 19 anos (%)
# * thinness 5-9 years - Prevalência de magreza em crianças de 5 a 9 anos (%)
# * Income composition of resources - Índice de Desenvolvimento Humano em termos de composição da renda dos recursos (índice variando de 0 a 1)
# * Schooling - Escolarização, número de anos de escolaridade (anos)

# %% [markdown]
# ## *Importações*

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/expectancy.csv')

# %%
df
# Out:
#       Unnamed: 0            Country  Year      Status  Life expectancy  \
# 0              0        Afghanistan  2O15  Developing             65.0
# 1              1        Afghanistan  2O14  Developing             59.9
# 2              2        Afghanistan  2O13  Developing             59.9
# 3              3        Afghanistan  2O12  Developing             59.5
# 4              4        Afghanistan  2O11  Developing             59.2
# ...          ...                ...   ...         ...              ...
# 2943         840  Equatorial Guinea  2OO9  Developing             55.7
# 2944        1037             Greece  2OO4  Developing             79.2
# 2945        2399       South Africa  2OO9  Developing             56.5
# 2946         678             Cyprus  2O1O   Developed             79.5
# 2947         196         Bangladesh  2O11  Developing             73.0
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2948 entries, 0 to 2947
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       2948 non-null   int64
#  1   Country                          2948 non-null   object
#  2   Year                             2948 non-null   object
#  3   Status                           2948 non-null   object
#  4   Life expectancy                  2938 non-null   float64
#  5   Adult Mortality                  2938 non-null   float64
#  6   infant deaths                    2948 non-null   int64
#  7   Alcohol                          2754 non-null   float64
#  8   percentage expenditure           2948 non-null   float64
#  9   Hepatitis B                      2392 non-null   float64
#  10  Measles                          2948 non-null   int64
#  11  BMI                              2914 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unnamed: 0  Life expectancy  Adult Mortality  infant deaths  \
# count  2948.000000      2938.000000      2938.000000    2948.000000
# mean   1470.252035        69.226344       164.723281      30.286635
# std     849.733306         9.525726       124.407794     117.749239
# min       0.000000        36.300000         1.000000       0.000000
# 25%     734.750000        63.100000        74.000000       0.000000
# 50%    1469.500000        72.100000       144.000000       3.000000
# 75%    2206.250000        75.700000       227.750000      22.000000
# max    2942.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B        Measles  \
# count  2754.000000             2948.000000  2392.000000    2948.000000
# mean      4.606961              737.190647    80.932692    2422.627883
# std       4.053810             1984.794497    25.084151   11453.807243
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                           0
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        556
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         653
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %% [markdown]
# # **1. Análise Exploratória Geral**
#
# Responda às seguintes perguntas:
#
#
# 1.   Quantas linhas e colunas temos no nosso dataset?
# 2.   Temos dados nulos? Se sim, qual a porcentagem deles? É uma porcentagem significativa?
# 3. Sobre os dados nulos com maior porcentagem, qual o tipo deles? Tente pensar em hipóteses do porquê eles estão nulos.
# 4. Existem duplicatas?
# 5. Todas as colunas estão com o seu tipo correto?
# 6. Como verificar as principais estatísticas das colunas numéricas? Escolha uma coluna com valores nulos para verificar como a média, moda, mediana.

# %% [markdown]
# ### 1. Quantas linhas e colunas temos no nosso dataset?

# %%
print(f'O dataset contém {df.shape[0]} linhas')
print(f'O dataset contém {df.shape[1]} colunas')
# Out:
# O dataset contém 2948 linhas
# O dataset contém 23 colunas

# %% [markdown]
# ### 2. Temos dados nulos? Se sim, qual a porcentagem deles? É uma porcentagem significativa?

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                           0
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        556
# Measles                              0
# BMI                                 34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                         653
# thinness  1-19 years                34
# thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
porcentagem = (df.isnull().sum() / df.shape[0]) * 100
porcentagem.sort_values(ascending=False)
# Out:
# Population                         22.150611
# Hepatitis B                        18.860244
# GDP                                15.196744
# Total expenditure                   7.666214
# Alcohol                             6.580733
# Income composition of resources     5.664858
# Schooling                           5.529172
# thinness 5-9 years                  1.153324
# thinness  1-19 years                1.153324
# BMI                                 1.153324
# Diphtheria                          0.644505
# Polio                               0.644505
# Life expectancy                     0.339213
# Adult Mortality                     0.339213
# Unnamed: 0                          0.000000
# infant deaths                       0.000000
# Status                              0.000000
# Country                             0.000000
# Year                                0.000000
# under-five deaths                   0.000000
# Measles                             0.000000
# ...

# %% [markdown]
# ### 3. Sobre os dados nulos com maior porcentagem, qual o tipo deles? Tente pensar em hipóteses do porquê eles estão nulos.

# %%
df_nulos_pop = df[df['Population'].isnull()]

# %%
df_nulos_pop.head(50)
# Out:
#      Unnamed: 0              Country  Year      Status  Life expectancy  \
# 64           64  Antigua and Barbuda  2O15  Developing             76.4
# 65           65  Antigua and Barbuda  2O14  Developing             76.2
# 66           66  Antigua and Barbuda  2O13  Developing             76.1
# 67           67  Antigua and Barbuda  2O12  Developing             75.9
# 68           68  Antigua and Barbuda  2O11  Developing             75.7
# 69           69  Antigua and Barbuda  2O1O  Developing             75.6
# 70           70  Antigua and Barbuda  2OO9  Developing             75.4
# 71           71  Antigua and Barbuda  2OO8  Developing             75.2
# 72           72  Antigua and Barbuda  2OO7  Developing             75.0
# 73           73  Antigua and Barbuda  2OO6  Developing             74.8
# 74           74  Antigua and Barbuda  2OO5  Developing             74.6
# 75           75  Antigua and Barbuda  2OO4  Developing             74.4
# ...

# %%
df_nulos_pop['Country'].unique()
# Out:
# array(['Antigua and Barbuda', 'Bahamas', 'Bahrain', 'Barbados',
#        'Bolivia (Plurinational State of)', 'Brunei Darussalam',
#        "Côte d'Ivoire", 'Congo', 'Cook Islands', 'Cuba', 'Czechia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Dominica', 'Egypt', 'Eritrea',
#        'Gambia', 'Grenada', 'Iran (Islamic Republic of)', 'Kuwait',
#        'Kyrgyzstan', "Lao People's Democratic Republic", 'Libya',
#        'Marshall Islands', 'Micronesia (Federated States of)', 'Monaco',
#        'Nauru', 'New Zealand', 'Niue', 'Oman', 'Qatar',
#        'Republic of Korea', 'Republic of Moldova',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia',
#        'Singapore', 'Slovakia', 'Somalia',
#        'The former Yugoslav republic of Macedonia',
#        'United Arab Emirates',
#        'United Kingdom of Great Britain and Northern Ireland',
# ...

# %%
df[df['Country'] == 'Egypt']
# Out:
#      Unnamed: 0 Country  Year      Status  Life expectancy  Adult Mortality  \
# 802         802   Egypt  2O15  Developing             79.0            159.0
# 803         803   Egypt  2O14  Developing             78.0            161.0
# 804         804   Egypt  2O13  Developing             79.0            159.0
# 805         805   Egypt  2O12  Developing             72.0            165.0
# 806         806   Egypt  2O11  Developing             74.0            168.0
# 807         807   Egypt  2O1O  Developing             70.0            173.0
# 808         808   Egypt  2OO9  Developing             69.9            174.0
# 809         809   Egypt  2OO8  Developing             69.8            172.0
# 810         810   Egypt  2OO7  Developing             69.7            171.0
# 811         811   Egypt  2OO6  Developing             69.5            175.0
# 812         812   Egypt  2OO5  Developing             69.4            174.0
# ...

# %%
df['Country'].value_counts()
# Out:
# Country
# Bahrain                  17
# Equatorial Guinea        17
# Bangladesh               17
# Croatia                  17
# Cyprus                   17
#                          ..
# Monaco                    1
# Marshall Islands          1
# Saint Kitts and Nevis     1
# San Marino                1
# Tuvalu                    1
# Name: count, Length: 193, dtype: int64

# %% [markdown]
# Os dados nulos da coluna Population são referentes aos países:
#
#
# 'Antigua and Barbuda', 'Bahamas', 'Bahrain', 'Barbados',
#        'Bolivia (Plurinational State of)', 'Brunei Darussalam',
#        "Côte d'Ivoire", 'Congo', 'Cook Islands', 'Cuba', 'Czechia',
#        "Democratic People's Republic of Korea",
#        'Democratic Republic of the Congo', 'Dominica', 'Egypt', 'Eritrea',
#        'Gambia', 'Grenada', 'Iran (Islamic Republic of)', 'Kuwait',
#        'Kyrgyzstan', "Lao People's Democratic Republic", 'Libya',
#        'Marshall Islands', 'Micronesia (Federated States of)', 'Monaco',
#        'Nauru', 'New Zealand', 'Niue', 'Oman', 'Qatar',
#        'Republic of Korea', 'Republic of Moldova',
#        'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Vincent and the Grenadines', 'San Marino', 'Saudi Arabia',
#        'Singapore', 'Slovakia', 'Somalia',
#        'The former Yugoslav republic of Macedonia',
#        'United Arab Emirates',
#        'United Kingdom of Great Britain and Northern Ireland',
#        'United Republic of Tanzania', 'United States of America',
#        'Venezuela (Bolivarian Republic of)', 'Viet Nam', 'Yemen'
#
# e são dados que existem na internet sobre o número dessas populações nas datas especificadas. Então é um caso de **missing completely at random**, porque não tem um padrão nos países que estão sem dados de população.

# %% [markdown]
# ### 4. Existem duplicatas?

# %%
df.duplicated().sum()
# Out:
# np.int64(5)

# %% [markdown]
# Sim, temos 5 linhas duplicadas.

# %% [markdown]
# ### 5. Todas as colunas estão com o seu tipo correto?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2948 entries, 0 to 2947
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       2948 non-null   int64
#  1   Country                          2948 non-null   object
#  2   Year                             2948 non-null   object
#  3   Status                           2948 non-null   object
#  4   Life expectancy                  2938 non-null   float64
#  5   Adult Mortality                  2938 non-null   float64
#  6   infant deaths                    2948 non-null   int64
#  7   Alcohol                          2754 non-null   float64
#  8   percentage expenditure           2948 non-null   float64
#  9   Hepatitis B                      2392 non-null   float64
#  10  Measles                          2948 non-null   int64
#  11  BMI                              2914 non-null   float64
# ...

# %%
pd.set_option("display.max_columns", None)

# %%
df
# Out:
#       Unnamed: 0            Country  Year      Status  Life expectancy  \
# 0              0        Afghanistan  2O15  Developing             65.0
# 1              1        Afghanistan  2O14  Developing             59.9
# 2              2        Afghanistan  2O13  Developing             59.9
# 3              3        Afghanistan  2O12  Developing             59.5
# 4              4        Afghanistan  2O11  Developing             59.2
# ...          ...                ...   ...         ...              ...
# 2943         840  Equatorial Guinea  2OO9  Developing             55.7
# 2944        1037             Greece  2OO4  Developing             79.2
# 2945        2399       South Africa  2OO9  Developing             56.5
# 2946         678             Cyprus  2O1O   Developed             79.5
# 2947         196         Bangladesh  2O11  Developing             73.0
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# ...

# %% [markdown]
# A principal coluna com o tipo equivocado é a coluna Year que possui um "O" no lugar do 0, então, o ano, que era para ser numérico inteiro, está como object.

# %% [markdown]
# ### 6. Como verificar as principais estatísticas das colunas numéricas? Escolha uma coluna com valores nulos para verificar como a média, moda, mediana.

# %%
df.describe()
# Out:
#         Unnamed: 0  Life expectancy  Adult Mortality  infant deaths  \
# count  2948.000000      2938.000000      2938.000000    2948.000000
# mean   1470.252035        69.226344       164.723281      30.286635
# std     849.733306         9.525726       124.407794     117.749239
# min       0.000000        36.300000         1.000000       0.000000
# 25%     734.750000        63.100000        74.000000       0.000000
# 50%    1469.500000        72.100000       144.000000       3.000000
# 75%    2206.250000        75.700000       227.750000      22.000000
# max    2942.000000        89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B        Measles  \
# count  2754.000000             2948.000000  2392.000000    2948.000000
# mean      4.606961              737.190647    80.932692    2422.627883
# std       4.053810             1984.794497    25.084151   11453.807243
# ...

# %%
df['Population'].describe()
# Out:
# count    2.295000e+03
# mean     1.278354e+07
# std      6.096690e+07
# min      3.400000e+01
# 25%      1.947545e+05
# 50%      1.388115e+06
# 75%      7.417429e+06
# max      1.293859e+09
# Name: Population, dtype: float64

# %%
pd.set_option("display.float_format", "{:.2f}".format)

# %%
df['Population'].describe()
# Out:
# count         2295.00
# mean      12783540.55
# std       60966904.44
# min             34.00
# 25%         194754.50
# 50%        1388115.00
# 75%        7417429.00
# max     1293859294.00
# Name: Population, dtype: float64

# %%
df[df['Population'] == 34]
# Out:
#       Unnamed: 0   Country  Year      Status  Life expectancy  \
# 1614        1614  Maldives  2OO3  Developing            72.70
#
#       Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 1614           112.00              0     1.75                  491.50
#
#       Hepatitis B  Measles   BMI  under-five deaths  Polio  Total expenditure  \
# 1614        98.00       75 16.70                  0  98.00               5.90
#
#       Diphtheria  HIV/AIDS     GDP  Population  thinness  1-19 years  \
# 1614       98.00      0.10 3432.25       34.00                 14.60
#
#       thinness 5-9 years  Income composition of resources  Schooling
# 1614               14.70                             0.60      11.80

# %% [markdown]
# # **2. Análise Univariada**
#
# 7. Como as variáveis numéricas estão distribuídas? Alguma apresenta distribuição normal, ou todas são assimétricas?
# 8. Qual país aparece com maior frequência? E o menos frequente?
# 9. Existem mais países em desenvolvimento ou desenvolvidos?
# 10. Os outliers existentes são reais ou valores extremos que não condizem com a realidade?
# 11. Qual o ano que apresenta mais informações?
# 12. Como está a escolaridade média?

# %% [markdown]
# ### 7. Como as variáveis numéricas estão distribuídas? Alguma apresenta distribuição normal, ou todas são assimétricas?

# %%
# Seleciona colunas numéricas
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Plota distribuições
for col in num_cols:
    plt.figure(figsize=(8, 4))
    plt.hist(df[col].dropna(), bins=30)
    plt.title(f'Distribuição de {col}')
    plt.xlabel(col)
    plt.ylabel('Frequência')
    plt.show()

# %% [markdown]
# Todas as distribuições são assimétricas, nenhuma apresentando distribuição normal.

# %% [markdown]
# ### 8. Qual país aparece com maior frequência? E o menos frequente?

# %%
df['Country'].value_counts().head(20)
# Out:
# Country
# Bahrain                             17
# Equatorial Guinea                   17
# Bangladesh                          17
# Croatia                             17
# Cyprus                              17
# South Africa                        17
# Montenegro                          17
# Kenya                               17
# Greece                              17
# Syrian Arab Republic                17
# Austria                             16
# Bahamas                             16
# Australia                           16
# Afghanistan                         16
# Argentina                           16
# Albania                             16
# Algeria                             16
# Benin                               16
# Bhutan                              16
# Bolivia (Plurinational State of)    16
# Name: count, dtype: int64

# %%
df['Country'].value_counts().tail(20)
# Out:
# Country
# Tonga                                                   16
# Trinidad and Tobago                                     16
# Tunisia                                                 16
# Turkey                                                  16
# Zimbabwe                                                16
# United Kingdom of Great Britain and Northern Ireland    16
# Vanuatu                                                 16
# Venezuela (Bolivarian Republic of)                      16
# United States of America                                16
# Uruguay                                                 16
# Dominica                                                 1
# Cook Islands                                             1
# Palau                                                    1
# Niue                                                     1
# Nauru                                                    1
# Monaco                                                   1
# ...

# %% [markdown]
# Os países que mais aparece são: Bahrain, Equatorial Guinea, Bangladesh, Croatia, Cyprus, South Africa, Montenegro, Kenya, Greece
#
# Os países que menos aparece são: Tuvalu, San Marino, Saint Kitts and Nevis, Marshall Islands, Monaco, Nauru, Niue, Palau, Cook Islands, Dominica

# %% [markdown]
# ### 9. Existem mais países em desenvolvimento ou desenvolvidos?

# %%
df['Status'].value_counts()
# Out:
# Status
# Developing    2434
# Developed      514
# Name: count, dtype: int64

# %% [markdown]
# Existem muito mais países em desenvolvimento do que países desenvolvidos.

# %% [markdown]
# ### 10. Os outliers existentes são reais ou valores extremos que não condizem com a realidade?

# %%
df['Diphtheria'].describe()
# Out:
# count   2929.00
# mean      82.31
# std       23.74
# min        2.00
# 25%       78.00
# 50%       93.00
# 75%       97.00
# max       99.00
# Name: Diphtheria, dtype: float64

# %%
sns.boxplot(x=df['Diphtheria'])
plt.show()

# %%
df[df['Diphtheria'] == 2.00]
# Out:
#      Unnamed: 0            Country  Year      Status  Life expectancy  \
# 835         835  Equatorial Guinea  2O14  Developing            57.90
#
#      Adult Mortality  infant deaths  Alcohol  percentage expenditure  \
# 835            32.00              3     0.01                   13.40
#
#      Hepatitis B  Measles   BMI  under-five deaths  Polio  Total expenditure  \
# 835         2.00       13 24.00                  4  24.00               3.80
#
#      Diphtheria  HIV/AIDS    GDP  Population  thinness  1-19 years  \
# 835        2.00      4.40 192.60  1129424.00                  8.50
#
#      thinness 5-9 years  Income composition of resources  Schooling
# 835                8.40                             0.58       9.20

# %%
sns.boxplot(x=df['Income composition of resources'])
plt.show()

# %%
df['Income composition of resources'].describe()
# Out:
# count   2781.00
# mean       0.63
# std        0.21
# min        0.00
# 25%        0.49
# 50%        0.68
# 75%        0.78
# max        0.95
# Name: Income composition of resources, dtype: float64

# %%
sns.boxplot(x=df['Polio'])
plt.show()

# %%
sns.boxplot(x=df['Schooling'])
plt.show()

# %%
df['Schooling'].describe()
# Out:
# count   2785.00
# mean      11.99
# std        3.36
# min        0.00
# 25%       10.10
# 50%       12.30
# 75%       14.30
# max       20.70
# Name: Schooling, dtype: float64

# %% [markdown]
# Por mais que algumas variáveis possuem valores extremos, esses valores condizem com a realidade, principalmente porque existem aqueles que variam de 0 a 1, e outros casos (por exemplo o caso da escolaridade e cobertura vacinal) que os valores baixos correspondem a países com poucos recursos.

# %% [markdown]
# ### 11. Qual o ano que apresenta mais informações?

# %%
df['Year'].value_counts()
# Out:
# Year
# 2O13    193
# 2OO9    185
# 2OO6    185
# 2O11    184
# 2O1O    184
# 2OO4    184
# 2OO7    184
# 2O14    184
# 2OOO    184
# 2OO8    183
# 2O15    183
# 2O12    183
# 2OO5    183
# 2OO3    183
# 2OO2    183
# 2OO1    183
# Name: count, dtype: int64

# %% [markdown]
# Mesmo com o ano com o tipo de coluna como "object", conseguimos identificar que o ano com mais registros é 2013.

# %% [markdown]
# ### 12. Como está a escolaridade média?

# %%
df['Schooling'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Percebemos que a média de escolaridade entre os países analisados é entre 10 a 15 anos, valor que condiz com a realidade de anos que uma pessoa com ensino básico, fundamental e médio possui.

# %% [markdown]
# # **3. Análise Bivariada**
#
# 13. Países mais ricos vivem mais?
# 14. O nível de escolaridade influencia a expectativa de vida?
# 15. Países desenvolvidos consomem mais álcool?
# 16. A mortalidade infantil ainda é um problema em países em desenvolvimento?
# 17. Como a expectativa de vida evoluiu ao longo do tempo?
# 18. Países com maior investimento em saúde têm maior expectativa de vida?

# %% [markdown]
# ### 13. Países mais ricos vivem mais?

# %%
sns.scatterplot(data=df,
            x='GDP',
            y='Life expectancy')
plt.title("PIB vs Expectativa de Vida")
plt.show()

# %%
df[['GDP', 'Life expectancy']].corr()
# Out:
#                  GDP  Life expectancy
# GDP             1.00             0.46
# Life expectancy 0.46             1.00

# %%
sns.regplot(data=df,
            x='Income composition of resources',
            y='Life expectancy')
plt.title("IDH (income component) vs Expectativa de Vida")
plt.show()

# %%
df[['Income composition of resources', 'Life expectancy']].corr()
# Out:
#                                  Income composition of resources  \
# Income composition of resources                             1.00
# Life expectancy                                             0.72
#
#                                  Life expectancy
# Income composition of resources             0.72
# Life expectancy                             1.00

# %%
sns.barplot(data=df, x='Status', y='Life expectancy')
plt.title("Expectativa de Vida por Status (Desenvolvido vs Em desenvolvimento)")
plt.show()

# %% [markdown]
# Analisando IDH e status de desenvolvimento, percebemos que a expectativa de vida tende a aumentar com o aumento do IDH (o que também está relacionado a países desenvolvidos), porém, quando analisamos o PIB para verificar se países mais ricos vivem mais, não encontramos correlações significativas.

# %% [markdown]
# ### 14. O nível de escolaridade influencia a expectativa de vida?

# %%
sns.scatterplot(data=df,
                x='Schooling',
                y='Life expectancy')
plt.title("Expectativa de Vida por Grau de Escolaridade")
plt.show()

# %%
df[['Schooling', 'Life expectancy']].corr()
# Out:
#                  Schooling  Life expectancy
# Schooling             1.00             0.75
# Life expectancy       0.75             1.00

# %% [markdown]
# Países onde a população estuda mais tendem a apresentar maior expectativa de vida, mas essa relação pode ser influenciada por outros fatores, como desenvolvimento econômico e acesso à saúde.

# %% [markdown]
# ### 15. Países desenvolvidos consomem mais álcool?

# %%
sns.barplot(data=df, x='Status', y='Alcohol')
plt.title("Consumo de Álcool por Status de Desenvolvimento")
plt.show()

# %% [markdown]
# Aqui vemos uma grande diferença entre consumo de álcool para países desenvolvidos e em desenvolvimento

# %% [markdown]
# ### 16. A mortalidade infantil ainda é um problema em países em desenvolvimento?

# %%
df.groupby('Status')['infant deaths'].mean()
# Out:
# Status
# Developed     1.49
# Developing   36.37
# Name: infant deaths, dtype: float64

# %%
sns.barplot(data=df, x='Status', y='infant deaths')
plt.title("Mortalidade Infantil por Status de Desenvolvimento")
plt.show()

# %% [markdown]
# Sim, com as duas análises acima podemos perceber que ainda é um problema com uma diferença gritante entre países em desenvolvimento e países desenvolvidos

# %% [markdown]
# ### 17. Como a expectativa de vida evoluiu ao longo do tempo?

# %%
sns.lineplot(data=df,
             x='Year',
             y='Life expectancy')
plt.title("Evolução da Expectativa de Vida ao Longo do Tempo")
plt.xlabel("Ano")
plt.ylabel("Expectativa de Vida")
plt.show()

# %% [markdown]
# Aqui, optei por já fazer a alteração do tipo da coluna "Year" para numérica, para obter uma melhor visualização e poder fazer cálculos

# %%
# trocar a letra "O" por 0
df['Year'] = df['Year'].str.replace('O', '0')

# %%
# converte a coluna para inteiro
df['Year'] = df['Year'].astype(int)

# %%
sns.lineplot(data=df,
             x='Year',
             y='Life expectancy')
plt.title("Evolução da Expectativa de Vida ao Longo do Tempo")
plt.xlabel("Ano")
plt.ylabel("Expectativa de Vida")
plt.show()

# %%
df.groupby('Year')['Life expectancy'].mean()
# Out:
# Year
# 2000   66.67
# 2001   67.13
# 2002   67.35
# 2003   67.43
# 2004   67.71
# 2005   68.21
# 2006   68.73
# 2007   69.06
# 2008   69.43
# 2009   69.79
# 2010   70.10
# 2011   70.67
# 2012   70.92
# 2013   71.24
# 2014   71.57
# 2015   71.62
# Name: Life expectancy, dtype: float64

# %%
sns.lineplot(data=df,
             x='Year',
             y='Life expectancy',
             hue='Status')
plt.title("Expectativa de Vida ao Longo do Tempo (Desenvolvidos vs Em Desenvolvimento)")
plt.show()

# %% [markdown]
# Podemos perceber que a expectativa de vida está aumentando ao longo do tempo, tanto em países desenvolvidos quanto em países em desenvolvimento.

# %% [markdown]
# ### 18. Países com maior investimento em saúde têm maior expectativa de vida?

# %%
df[['Total expenditure', 'Life expectancy']].corr()
# Out:
#                    Total expenditure  Life expectancy
# Total expenditure               1.00             0.22
# Life expectancy                 0.22             1.00

# %%
sns.regplot(data=df,
            x='Total expenditure',
            y='Life expectancy')
plt.title("Investimento em Saúde vs Expectativa de Vida")
plt.show()

# %%
df[['percentage expenditure', 'Life expectancy']].corr()
# Out:
#                         percentage expenditure  Life expectancy
# percentage expenditure                    1.00             0.38
# Life expectancy                           0.38             1.00

# %%
sns.scatterplot(data=df,
            x='percentage expenditure',
            y='Life expectancy')
plt.title("Investimento em Saúde vs Expectativa de Vida")
plt.show()

# %% [markdown]
# Tendemos a pensar que sim, mas os gráficos não mostram uma correlação significativa entre esses dois fatores.

# %% [markdown]
# # **4. Processamento dos Dados**
#
# Nesta etapa, é necessário que você:
# * Faça a limpeza das colunas erradas;
# * Faça o tratamento dos valores nulos da forma que achar válido;
# * Trate as duplicatas;
# * Transforme as colunas categóricas em numéricas;
# * Faça o escalonamento de variáveis numéricas;

# %% [markdown]
# ## Limpeza das colunas

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2948 entries, 0 to 2947
# Data columns (total 23 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Unnamed: 0                       2948 non-null   int64
#  1   Country                          2948 non-null   object
#  2   Year                             2948 non-null   int64
#  3   Status                           2948 non-null   object
#  4   Life expectancy                  2938 non-null   float64
#  5   Adult Mortality                  2938 non-null   float64
#  6   infant deaths                    2948 non-null   int64
#  7   Alcohol                          2754 non-null   float64
#  8   percentage expenditure           2948 non-null   float64
#  9   Hepatitis B                      2392 non-null   float64
#  10  Measles                          2948 non-null   int64
#  11  BMI                              2914 non-null   float64
# ...

# %% [markdown]
# A coluna "Year" já foi tratada, agora precisamos remover a coluna Unnamed: 0

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2948 entries, 0 to 2947
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2948 non-null   object
#  1   Year                             2948 non-null   int64
#  2   Status                           2948 non-null   object
#  3   Life expectancy                  2938 non-null   float64
#  4   Adult Mortality                  2938 non-null   float64
#  5   infant deaths                    2948 non-null   int64
#  6   Alcohol                          2754 non-null   float64
#  7   percentage expenditure           2948 non-null   float64
#  8   Hepatitis B                      2392 non-null   float64
#  9   Measles                          2948 non-null   int64
#  10  BMI                              2914 non-null   float64
#  11  under-five deaths                2948 non-null   int64
# ...

# %% [markdown]
# ## Tratamento de Nulos

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Population                         653
# Hepatitis B                        556
# GDP                                448
# Total expenditure                  226
# Alcohol                            194
# Income composition of resources    167
# Schooling                          163
# thinness  1-19 years                34
# thinness 5-9 years                  34
# BMI                                 34
# Diphtheria                          19
# Polio                               19
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Status                               0
# Country                              0
# Year                                 0
# under-five deaths                    0
# Measles                              0
# percentage expenditure               0
# HIV/AIDS                             0
# dtype: int64

# %% [markdown]
# Aqui, para decidir o que fará com os nulos, irá depender da utilização dessas colunas para um modelo de machine learning, e do objetivo da análise.
#
# Como esta análise tem como intuito somente fazer uma análise exploratória, irei excluir as colunas com maior porcentagem de nulos, e excluir os dados nulos das demais.

# %%
# excluir colunas
df = df.drop(columns=['Population', 'Hepatitis B', 'GDP'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2948 entries, 0 to 2947
# Data columns (total 19 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2948 non-null   object
#  1   Year                             2948 non-null   int64
#  2   Status                           2948 non-null   object
#  3   Life expectancy                  2938 non-null   float64
#  4   Adult Mortality                  2938 non-null   float64
#  5   infant deaths                    2948 non-null   int64
#  6   Alcohol                          2754 non-null   float64
#  7   percentage expenditure           2948 non-null   float64
#  8   Measles                          2948 non-null   int64
#  9   BMI                              2914 non-null   float64
#  10  under-five deaths                2948 non-null   int64
#  11  Polio                            2929 non-null   float64
# ...

# %%
# excluir demais registros nulos
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Measles                            0
# BMI                                0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
# HIV/AIDS                           0
# thinness  1-19 years               0
# thinness 5-9 years                 0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %% [markdown]
# ### Tratamento de Duplicatas

# %%
# remove duplicatas
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ### Transformação de colunas categóricas em numéricas

# %%
cat_cols = df.select_dtypes(include=['object']).columns

# %%
# One Hot Encoding para transformar colunas categóricas em numéricas
df_encoded = pd.get_dummies(df, columns=cat_cols, drop_first=True)

# %%
df_encoded
# Out:
#       Year  Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0     2015            65.00           263.00             62     0.01
# 1     2014            59.90           271.00             64     0.01
# 2     2013            59.90           268.00             66     0.01
# 3     2012            59.50           272.00             69     0.01
# 4     2011            59.20           275.00             71     0.01
# ...    ...              ...              ...            ...      ...
# 2933  2004            44.30           723.00             27     4.36
# 2934  2003            44.50           715.00             26     4.06
# 2935  2002            44.80            73.00             25     4.43
# 2936  2001            45.30           686.00             25     1.72
# 2937  2000            46.00           665.00             24     1.68
#
#       percentage expenditure  Measles   BMI  under-five deaths  Polio  \
# ...

# %% [markdown]
# ### Escalonamento de variáveis numéricas

# %%
num_cols = df.select_dtypes(include=['int64', 'float64']).columns

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df_encoded[num_cols] = scaler.fit_transform(df_encoded[num_cols])

# %%
df_encoded
# Out:
#       Year  Life expectancy  Adult Mortality  infant deaths  Alcohol  \
# 0     1.85            -0.46             0.81           0.26    -1.13
# 1     1.61            -1.00             0.87           0.28    -1.13
# 2     1.38            -1.00             0.85           0.29    -1.13
# 3     1.15            -1.05             0.88           0.32    -1.13
# 4     0.92            -1.08             0.91           0.34    -1.13
# ...    ...              ...              ...            ...      ...
# 2933 -0.70            -2.66             4.51          -0.02    -0.05
# 2934 -0.93            -2.64             4.45          -0.03    -0.12
# 2935 -1.16            -2.61            -0.72          -0.04    -0.03
# 2936 -1.40            -2.56             4.22          -0.04    -0.71
# 2937 -1.63            -2.48             4.05          -0.05    -0.72
#
#       percentage expenditure  Measles   BMI  under-five deaths  Polio  \
# ...

# %% [markdown]
# Aqui, separei os tratamentos em um df diferente, para não impactar na etapa de Feature Engineer

# %% [markdown]
# # **5. Feature Engineer**
#
# É aqui que sua imaginação precisa fluir. Crie de duas a três novas variáveis relacionando as variáveis já existentes e explique como elas poderiam agregar na capacidade do modelo de prever expectativa de vida.

# %% [markdown]
# ### Índice de mortalidade total

# %%
# índice de mortalidade total
df['Mortality_index'] = (
    df['Adult Mortality'] * 0.5 +
    df['infant deaths'] * 0.3 +
    df['under-five deaths'] * 0.2
)

# %%
df[['under-five deaths', 'Life expectancy']].corr()
# Out:
#                    under-five deaths  Life expectancy
# under-five deaths               1.00            -0.20
# Life expectancy                -0.20             1.00

# %%
df[['infant deaths', 'Life expectancy']].corr()
# Out:
#                  infant deaths  Life expectancy
# infant deaths             1.00            -0.18
# Life expectancy          -0.18             1.00

# %%
df[['Adult Mortality', 'Life expectancy']].corr()
# Out:
#                  Adult Mortality  Life expectancy
# Adult Mortality             1.00            -0.68
# Life expectancy            -0.68             1.00

# %%
df[['Mortality_index', 'Life expectancy']].corr()
# Out:
#                  Mortality_index  Life expectancy
# Mortality_index             1.00            -0.57
# Life expectancy            -0.57             1.00

# %% [markdown]
# Criando o índice de mortalidade total, podemos aumentar a correlação das variáveis de mortalidade infantil com a variável target

# %% [markdown]
# ### Cobertura vacinal total

# %%
df['Vaccination_total'] = df[['Polio', 'Diphtheria']].mean(axis=1)

# %%
df['Vaccination_total'].describe()
# Out:
# count   2556.00
# mean      82.81
# std       21.12
# min        3.00
# 25%       76.50
# 50%       93.00
# 75%       97.00
# max       99.00
# Name: Vaccination_total, dtype: float64

# %%
df['Vaccination_total'].hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Grau de educação

# %%
df['Schooling_level'] = pd.cut(
    df['Schooling'],
    bins=[0, 8, 12, 16, 30],
    labels=['Primary', 'Secondary', 'Undergraduate', 'Postgraduate'],
    include_lowest=True
)

# %%
df['Schooling_level'].value_counts()
# Out:
# Schooling_level
# Undergraduate    1147
# Secondary         897
# Primary           278
# Postgraduate      234
# Name: count, dtype: int64
