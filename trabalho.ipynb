# %% [markdown]
# ## Atividade 1: Contar Frequência de Palavras
#
# 1. Crie uma variável texto com uma frase de sua escolha.
#
# 2. Crie um dicionário vazio chamado contagem_palavras.
#
# 3. Separe a frase em palavras (dica: use o método .split()).
#
# 4. Use um laço de repetição for para percorrer a lista de palavras.
#
# 5. Dentro do loop, use um condicional (if/else) para verificar se a palavra já é uma chave no dicionário contagem_palavras.
#
# 6. Se a palavra existir, incremente seu valor em 1.
#
# 7. Se não existir, adicione a palavra como uma nova chave com o valor 1.
#
# 8. Ao final, imprima o dicionário contagem_palavras.

# %%
# Escreva o código aqui
texto = "curso Facens - Primeiro dia de aula do curso IA da Facens"
contagem_palavras = {}

for item in texto.split():
  if item in contagem_palavras:
    #"encontrou"
    contagem_palavras[item] += 1
  else:
    #Nao encontrou
    contagem_palavras[item] = 1

print(contagem_palavras)
# Out:
# {'curso': 2, 'Facens': 2, '-': 1, 'Primeiro': 1, 'dia': 1, 'de': 1, 'aula': 1, 'do': 1, 'IA': 1, 'da': 1}

# %% [markdown]
# ## Atividade 2: Analisar Dados de Alunos
#
# 1. Crie uma lista chamada alunos, onde cada item é um dicionário com as chaves "nome" e "nota". Adicione pelo menos 4 alunos.
#
# 2. Crie uma variável soma_notas e inicialize-a com 0.
#
# 3. Crie uma variável melhor_aluno como um dicionário vazio.
#
# 4. Use um laço de repetição for para iterar sobre a lista alunos.
#
# 5. Dentro do loop, adicione a nota de cada aluno à soma_notas.
#
# 6. Use um condicional para verificar se a nota do aluno atual é maior que a nota armazenada em melhor_aluno. Se sim, atualize o dicionário melhor_aluno com os dados do aluno atual.
#
# 7. Após o loop, calcule a média da turma (soma_notas dividida pelo número de alunos) e imprima o nome do aluno com a maior nota e a média da turma.

# %%
# Escreva o código aqui
alunos = [{"nome": "Jose","nota":8},
          {"nome": "Antonio","nota":5},
          {"nome": "Maria","nota":10},
          {"nome": "Joana","nota":7},
          ]
soma_notas = 0
melhor_aluno = {}

for aluno in alunos:
   soma_notas += aluno["nota"]  

   #pimeira execução - not melhor_aluno
   if not melhor_aluno or aluno["nota"] > melhor_aluno["nota"]:
      melhor_aluno= aluno
media_turma = soma_notas/ len(alunos) 
     
print(f"Nome do aluno com a maior nota: {melhor_aluno['nome']}")
print(f"Média da turma: {media_turma}")
# Out:
# Nome do aluno com a maior nota Maria
# Média da turma 7.5

# %% [markdown]
# ## Atividade 3: Gerar um Tabuleiro de Xadrez
#
# 1. Crie uma lista vazia chamada tabuleiro.
#
# 2. Use um laço de repetição for externo para iterar 8 vezes (representando as linhas).
#
# 3. Dentro dele, crie uma lista vazia chamada linha.
#
# 4. Use um laço de repetição for interno para iterar 8 vezes (representando as colunas).
#
# 5. Dentro do loop interno, use um condicional para adicionar uma string que representa a cor da casa ('preto' ou 'branco') à linha, alternando a cor a cada passo.
#
# 6. Adicione a linha completa ao tabuleiro após o loop interno.
#
# 7. Imprima o tabuleiro completo.

# %%
# Escreva o código aqui
tabuleiro = []

for l in range(8):
    linha = []
    for col in range(8):
       if (l + col) % 2 == 0:
            linha.append('preto')
       else:
            linha.append('branco')

    tabuleiro.append(linha)

for linha in tabuleiro:
    print(linha)
# Out:
# ['preto', 'branco', 'preto', 'branco', 'preto', 'branco', 'preto', 'branco']
# ['branco', 'preto', 'branco', 'preto', 'branco', 'preto', 'branco', 'preto']
# ['preto', 'branco', 'preto', 'branco', 'preto', 'branco', 'preto', 'branco']
# ['branco', 'preto', 'branco', 'preto', 'branco', 'preto', 'branco', 'preto']
# ['preto', 'branco', 'preto', 'branco', 'preto', 'branco', 'preto', 'branco']
# ['branco', 'preto', 'branco', 'preto', 'branco', 'preto', 'branco', 'preto']
# ['preto', 'branco', 'preto', 'branco', 'preto', 'branco', 'preto', 'branco']
# ['branco', 'preto', 'branco', 'preto', 'branco', 'preto', 'branco', 'preto']

# %% [markdown]
# ## Atividade 4: Análise de Dados de Sensores
#
# 1. Crie uma lista de dicionários chamada leituras_sensores, onde cada dicionário tem as chaves "sensor_id", "valor" (numérico) e "data" (string). Adicione pelo menos 5 leituras.
#
# 2. Crie variáveis para a soma dos valores, o maior valor, o menor valor e a contagem de leituras.
#
# 3. Crie um dicionário vazio chamado alertas para armazenar leituras com valor acima de um limite (por exemplo, 30).
#
# 4. Use um laço de repetição for para percorrer a lista leituras_sensores.
#
# 5. Dentro do loop, atualize as variáveis de soma, maior e menor valor.
#
# 6. Use um condicional (if) para verificar se o valor da leitura é maior que o limite. Se sim, adicione a leitura completa ao dicionário alertas com o sensor_id como chave.
#
# 7. Após o loop, calcule a média dos valores e imprima um relatório com o valor médio, o maior valor, o menor valor e o dicionário alertas com as leituras que ultrapassaram o limite.

# %%
# Escreva o código aqui
leituras_sensores= [{"sensor_id":"1020", "valor":10, "data":"20250913"},
                    {"sensor_id":"2024", "valor":20, "data":"20250913"},
                    {"sensor_id":"9870", "valor":100, "data":"20250913"},
                    {"sensor_id":"14236", "valor":50, "data":"20250913"},
                    {"sensor_id":"5879", "valor":80, "data":"20250913"}]
soma_valores = 0
maior_valor=0
menor_valor =0
contagem_leituras =0
alertas ={}
limite = 30

for item in leituras_sensores:

    soma_valores += item["valor"]
    contagem_leituras += 1

    if item["valor"]> maior_valor:
       maior_valor = item["valor"]
    
    if item["valor"]< menor_valor:
       menor_valor = item["valor"]

    if item["valor"]> limite:
       alertas[item["sensor_id"]] = item
          
media_valores = soma_valores / contagem_leituras


print(f"O valor médio: {media_valores}")
print(f"O maior valor: {maior_valor}")
print(f"O menor valor: {menor_valor}") 
print(f"O dicionário alertas com as leituras que ultrapassaram o limite {alertas}")
# Out:
# O valor médio: 52.0
# O maior valor: 100
# O menor valor: 0
# O dicionário alertas com as leituras que ultrapassaram o limite {'9870': {'sensor_id': '9870', 'valor': 100, 'data': '20250913'}, '14236': {'sensor_id': '14236', 'valor': 50, 'data': '20250913'}, '5879': {'sensor_id': '5879', 'valor': 80, 'data': '20250913'}}

# %% [markdown]
# ## Atividade 5: Consolidação e Limpeza de Dados de Múltiplas Fontes
#
# 1. Crie duas listas de dicionários, sensores_leste e sensores_oeste, cada uma com pelo menos 3 dicionários. Cada dicionário deve ter as chaves "id", "temperatura" (numérico) e "umidade" (numérico). Inclua valores negativos ou nulos para simular dados inválidos.
#
# 2. Crie uma lista vazia chamada dados_validos.
#
# 3. Use loops de repetição para percorrer as duas listas de sensores. Dentro dos loops, use condicionais (if) para verificar se os valores de "temperatura" e "umidade" são positivos.
#
# 4. Se os dados forem válidos, adicione o dicionário completo à lista dados_validos.
#
# 5. Após os loops, use um laço for para iterar sobre a lista dados_validos. Calcule e armazene a temperatura média, a umidade média, a temperatura máxima e a umidade máxima.
#
# 6. Use um dicionário para contar o número de leituras válidas de cada sensor (usando o "id" como chave).
#
# 7. Imprima um relatório final com as médias, os valores máximos e a contagem de leituras por sensor.

# %%
# Escreva o código aqui
sensores_leste =[{"id":"100","temperatura":10, "umidade":80}, 
                 {"id":"20","temperatura":35, "umidade":50},
                 {"id":"100","temperatura":None, "umidade":45} #invalido
                 ]
sensores_oeste =[{"id":"45","temperatura":-1, "umidade":50}, #invalido
                 {"id":"","temperatura":None, "umidade":None}, #invalido
                 {"id":"100","temperatura":25, "umidade":35}
                 ]
dados_validos =[]

for s_leste in sensores_leste:
    if s_leste['temperatura'] is not None and s_leste["umidade"] is not None and s_leste['temperatura']>0 and s_leste["umidade"] >0:
        dados_validos.append(s_leste)


for s_oeste in sensores_oeste:
    if s_oeste['temperatura']is not None and s_oeste["umidade"] is not None and s_oeste['temperatura']>0 and s_oeste["umidade"] >0 :
        dados_validos.append(s_oeste) 

temperatura_maxima = 0
umidade_maxima = 0
soma =0
umidade =0
contagem_sensores = {}

for dados in dados_validos:
    soma += dados['temperatura']
    umidade += dados['umidade']
    
    if dados["temperatura"] > temperatura_maxima:
        temperatura_maxima = dados["temperatura"]
        
    if dados["umidade"] > umidade_maxima:
        umidade_maxima = dados["umidade"]
    
    # 6. Atualize a contagem de leituras por sensor
    id = dados['id']
    if id in contagem_sensores:
        contagem_sensores[id] += 1
    else:
        contagem_sensores[id] = 1

temperatura_media = round(soma/len(dados_validos),2)
umidade_media = umidade/len(dados_validos)


print(f"A temperatura média:{temperatura_media} C")
print(f"A umidade média: {umidade_media}")
print(f"A temperatura máxima: {temperatura_maxima} C")
print(f"A umidade máxima:{umidade_maxima}")

print(f"Contagem por sensor: {contagem_sensores}")
# Out:
# A temperatura média:23.33 C
# A umidade média: 55.0
# A temperatura máxima: 35 C
# A umidade máxima:80
# Contagem por sensor: {'100': 2, '20': 1}

# %%
sensores_leste = [
    {"id": "leste-01", "temperatura": 25.5, "umidade": 65.0},
    {"id": "leste-02", "temperatura": 30.1, "umidade": 72.5},
    {"id": "leste-03", "temperatura": -5.0, "umidade": 50.0},  # Dado inválido (temperatura)
    {"id": "leste-04", "temperatura": 28.0, "umidade": -10.0}   # Dado inválido (umidade)
]

sensores_oeste = [
    {"id": "oeste-01", "temperatura": 22.8, "umidade": 80.0},
    {"id": "oeste-02", "temperatura": 35.0, "umidade": 75.2},
    {"id": "oeste-03", "temperatura": 26.3, "umidade": 0},      # Dado inválido (umidade)
    {"id": "oeste-04", "temperatura": 19.5, "umidade": 68.1}
]

# 2. Crie uma lista vazia chamada dados_validos.
dados_validos = []

# 3. Use loops de repetição para percorrer as duas listas de sensores.
for leitura in sensores_leste:
    # 4. Verifique se os dados são válidos (temperatura e umidade positivas)
    if leitura["temperatura"] > 0 and leitura["umidade"] > 0:
        dados_validos.append(leitura)

for leitura in sensores_oeste:
    if leitura["temperatura"] > 0 and leitura["umidade"] > 0:
        dados_validos.append(leitura)

# 5. Inicialize as variáveis para os cálculos
soma_temperatura = 0
soma_umidade = 0
max_temperatura = float('-inf')  # Inicializa com o menor número possível
max_umidade = float('-inf')

# 6. Crie um dicionário para contar as leituras válidas de cada sensor.
contagem_sensores = {}

for leitura in dados_validos:
    # 5. Calcule a soma e os valores máximos
    soma_temperatura += leitura["temperatura"]
    soma_umidade += leitura["umidade"]
    
    if leitura["temperatura"] > max_temperatura:
        max_temperatura = leitura["temperatura"]
        
    if leitura["umidade"] > max_umidade:
        max_umidade = leitura["umidade"]
    
    # 6. Atualize a contagem de leituras por sensor
    sensor_id = leitura["id"]
    if sensor_id in contagem_sensores:
        contagem_sensores[sensor_id] += 1
    else:
        contagem_sensores[sensor_id] = 1

# Calcule as médias
if dados_validos:
    media_temperatura = soma_temperatura / len(dados_validos)
    media_umidade = soma_umidade / len(dados_validos)
else:
    media_temperatura = 0
    media_umidade = 0

# 7. Imprima o relatório final
print("--- Relatório de Sensores Válidos ---")
print(f"Número de leituras válidas: {len(dados_validos)}")
print(f"Temperatura Média: {media_temperatura:.2f}°C")
print(f"Umidade Média: {media_umidade:.2f}%")
print(f"Temperatura Máxima: {max_temperatura}°C")
print(f"Umidade Máxima: {max_umidade}%")
print("\n--- Contagem de Leituras por Sensor ---")
for sensor, contagem in contagem_sensores.items():
    print(f"Sensor {sensor}: {contagem} leituras")
# Out:
# --- Relatório de Sensores Válidos ---
# Número de leituras válidas: 5
# Temperatura Média: 26.58°C
# Umidade Média: 72.16%
# Temperatura Máxima: 35.0°C
# Umidade Máxima: 80.0%
#
# --- Contagem de Leituras por Sensor ---
# Sensor leste-01: 1 leituras
# Sensor leste-02: 1 leituras
# Sensor oeste-01: 1 leituras
# Sensor oeste-02: 1 leituras
# Sensor oeste-04: 1 leituras
